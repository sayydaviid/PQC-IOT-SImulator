# %%
from pqc_iot_simulator.pqc_iot_sim.components import Network, Logger
from pqc_iot_simulator.pqc_iot_sim.engines import MininetWiFiEngine

Logger.activate()
# Out:
# [INFO] Logger ativado

# %%
CRYPTO_MODE = "hybrid"

SOURCE = "iot_1"
DESTINATION = "server_1"

PAYLOAD = {
    "sensor": "temperatura",
    "valor": 28.5,
    "unidade": "celsius",
    "mensagem": "teste classico no jupyter"
}

# %%
rede = Network(verbose=True)

rede.set_ready_topology("grade", 3, 3)
rede.set_protocol("mqtt")
rede.set_crypto_mode(CRYPTO_MODE)

print(rede.summary())
# Out:
# [INFO] 2026/04/27 20:44:05 | MetricsCollector | MetricsCollector criado | {}
# [INFO] 2026/04/27 20:44:05 | CryptoManager | CryptoManager criado | {'mode': 'classical', 'backend': 'cryptography', 'kem': 'ML-KEM-512', 'pqc_signature': 'ML-DSA-44', 'classical_signature': 'ed25519', 'use_classical_signature': True, 'use_pqc_signature': True}
# [INFO] 2026/04/27 20:44:05 | Network | Rede criada | {'name': 'default_network'}
# [INFO] 2026/04/27 20:44:05 | Network | Iniciando criacao da topologia | {'topology': 'grade', 'args': (3, 3), 'kwargs': {}}
# [INFO] 2026/04/27 20:44:05 | Network | Gerando topologia em grade | {'rows': 3, 'cols': 3}
# [INFO] 2026/04/27 20:44:05 | MetricsCollector | Metricas apagadas | {}
# [INFO] 2026/04/27 20:44:05 | Network | Grafo sincronizado | {'nodes': 9, 'edges': 12}
# [INFO] 2026/04/27 20:44:05 | Network | Topologia criada com sucesso | {'topology': 'grade', 'params': {'rows': 3, 'cols': 3}, 'nodes': 9, 'links': 12}
# [INFO] 2026/04/27 20:44:05 | Network | Protocolo definido | {'protocol': 'mqtt', 'params': {}, 'hosts_updated': 0}
# [INFO] 2026/04/27 20:44:05 | CryptoManager | CryptoManager configurado | {'mode': 'hybrid', 'backend': 'cryptography + liboqs', 'kem': 'ML-KEM-512', 'pqc_signature': 'ML-DSA-44', 'classical_signature': 'ed25519', 'use_classical_signature': True, 'use_pqc_signature': True}
# [INFO] 2026/04/27 20:44:05 | Network | Modo criptografico definido | {'mode': 'hybrid', 'params': {}, 'crypto_config': {'mode': 'hybrid', 'backend': 'cryptography + liboqs', 'kem': 'ML-KEM-512', 'pqc_signature': 'ML-DSA-44', 'classical_signature': 'ed25519', 'use_classical_signature': True, 'use_pqc_signature': True}, 'hosts_updated': 0}
# [INFO] 2026/04/27 20:44:05 | Network | Resumo da rede solicitado | {'total_nodes': 9, 'total_links': 12, 'total_hosts': 0, 'runtime_engine': None}
# {'name': 'default_network', 'engine': None, 'runtime_engine': None, 'runtime_engine_type': None, 'topology': 'grade', 'topology_params': {'rows': 3, 'cols': 3}, 'crypto_mode': 'hybrid', 'crypto_params': {}, 'crypto_config': {'mode': 'hybrid', 'backend': 'cryptography + liboqs', 'kem': 'ML-KEM-512', 'pqc_signature': 'ML-DSA-44', 'classical_signature': 'ed25519', 'use_classical_signature': True, 'use_pqc_signature': True}, 'protocol': 'mqtt', 'protocol_params': {}, 'metrics': [], 'nodes': ['iot_1', 'iot_2', 'iot_3', 'iot_6', 'iot_5', 'iot_4', 'iot_7', 'gateway_1', 'server_1'], 'links': [('gateway_1', 'server_1'), ('iot_6', 'iot_7'), ('iot_5', 'iot_6'), ('iot_1', 'iot_2'), ('iot_3', 'iot_4'), ('iot_2', 'iot_3'), ('gateway_1', 'iot_7'), ('iot_1', 'iot_6'), ('iot_2', 'iot_5'), ('iot_4', 'iot_5'), ('iot_4', 'server_1'), ('gateway_1', 'iot_5')], 'hosts': [], 'total_nodes': 9, 'total_links': 12, 'total_hosts': 0}

# %%
engine = MininetWiFiEngine(
    network=rede,
    logger=rede.logger,
    default_bw=10,
    default_delay="5ms",
    default_loss=0,
    link_mode="infrastructure",
    open_cli_on_start=False
)

print("Engine criada")
# Out:
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Engine criada | {'name': 'mininet_wifi_engine', 'engine_type': 'mininet_wifi'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Engine configurada | {'ip_base': '10.0.0.', 'ip_prefix': 24, 'ssid': 'pqc_iot_sim', 'mode': 'g', 'channel': '1', 'default_bw': 10, 'default_delay': '5ms', 'default_loss': 0, 'auto_set_positions': True, 'open_cli_on_start': False, 'link_mode': 'infrastructure', 'station_range': 200, 'ap_range': 200, 'association_wait_seconds': 1.0}
# Engine criada

# %%
engine.build()
engine.start()

print("Engine iniciada")
# Out:
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Network validada para engine | {'nodes': 9, 'links': 12}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Nos mapeados para engine | {'nodes': [{'node_id': 'iot_1', 'node_type': 'iot', 'mininet_name': 'sta1', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_1'}}, {'node_id': 'iot_2', 'node_type': 'iot', 'mininet_name': 'sta2', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_2'}}, {'node_id': 'iot_3', 'node_type': 'iot', 'mininet_name': 'sta3', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_3'}}, {'node_id': 'iot_6', 'node_type': 'iot', 'mininet_name': 'sta6', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_6'}}, {'node_id': 'iot_5', 'node_type': 'iot', 'mininet_name': 'sta5', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_5'}}, {'node_id': 'iot_4', 'node_type': 'iot', 'mininet_name': 'sta4', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_4'}}, {'node_id': 'iot_7', 'node_type': 'iot', 'mininet_name': 'sta7', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'iot_7'}}, {'node_id': 'gateway_1', 'node_type': 'gateway', 'mininet_name': 'ap1', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'gateway_1'}}, {'node_id': 'server_1', 'node_type': 'server', 'mininet_name': 'h1', 'ip': None, 'mac': None, 'metadata': {'original_node_id': 'server_1'}}]}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Links de infraestrutura mapeados para engine | {'gateway': 'gateway_1', 'servers': ['server_1'], 'links': [{'source': 'gateway_1', 'target': 'server_1', 'source_mininet': 'ap1', 'target_mininet': 'h1'}], 'note': 'IoTs nao recebem addLink direto com AP; associacao e wireless.'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Engine preparada | {'engine_nodes': 9, 'engine_links': 1}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Criando objeto Mininet WiFi | {'nodes': 9, 'links': 1, 'link_mode': 'infrastructure'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'net', 'type': 'Mininet_wifi'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'controller', 'type': 'Controller'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | IPs atribuidos aos nos da engine | {'iot_1': '10.0.0.1/24', 'iot_2': '10.0.0.2/24', 'iot_3': '10.0.0.3/24', 'iot_6': '10.0.0.4/24', 'iot_5': '10.0.0.5/24', 'iot_4': '10.0.0.6/24', 'iot_7': '10.0.0.7/24', 'gateway_1': '10.0.0.250/24', 'server_1': '10.0.0.200/24'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Posicoes atribuidas aos nos da engine | {'iot_1': '20,20,0', 'iot_2': '55,20,0', 'iot_3': '90,20,0', 'iot_6': '20,55,0', 'iot_5': '55,55,0', 'iot_4': '90,55,0', 'iot_7': '20,90,0', 'gateway_1': '55,90,0', 'server_1': '90,90,0'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_1', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_2', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_3', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_6', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_5', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_4', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:05 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'iot_7', 'type': 'Station'}
# [INFO] 2026/04/27 20:44:06 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'gateway_1', 'type': 'OVSAP'}
# [INFO] 2026/04/27 20:44:06 | mininet_wifi_engine | Objeto de runtime registrado | {'key': 'server_1', 'type': 'Host'}
# [INFO] 2026/04/27 20:44:06 | mininet_wifi_engine | Nos criados no Mininet WiFi | {'nodes': {'iot_1': {'mininet_name': 'sta1', 'type': 'iot', 'ip': '10.0.0.1/24'}, 'iot_2': {'mininet_name': 'sta2', 'type': 'iot', 'ip': '10.0.0.2/24'}, 'iot_3': {'mininet_name': 'sta3', 'type': 'iot', 'ip': '10.0.0.3/24'}, 'iot_6': {'mininet_name': 'sta6', 'type': 'iot', 'ip': '10.0.0.4/24'}, 'iot_5': {'mininet_name': 'sta5', 'type': 'iot', 'ip': '10.0.0.5/24'}, 'iot_4': {'mininet_name': 'sta4', 'type': 'iot', 'ip': '10.0.0.6/24'}, 'iot_7': {'mininet_name': 'sta7', 'type': 'iot', 'ip': '10.0.0.7/24'}, 'gateway_1': {'mininet_name': 'ap1', 'type': 'gateway', 'ip': '10.0.0.250/24'}, 'server_1': {'mininet_name': 'h1', 'type': 'server', 'ip': '10.0.0.200/24'}}}
# [INFO] 2026/04/27 20:44:06 | mininet_wifi_engine | Configurando nos WiFi | {}
# *** sta1-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** sta2-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** sta3-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** sta6-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** sta5-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** sta4-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** sta7-wlan0: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# *** ap1-wlan1: requested 200.00m -> effective 200.00m (delta +0.00m) using tx power 9 dBm
# (10.00Mbit 5ms delay 0.00000% loss) (10.00Mbit 5ms delay 0.00000% loss) sta1 is already connected!
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Criando link no Mininet WiFi | {'source': 'gateway_1', 'target': 'server_1', 'source_mininet': 'ap1', 'target_mininet': 'h1', 'params': {'bw': 10, 'delay': '5ms', 'loss': 0}, 'link_mode': 'infrastructure'}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Links criados no Mininet WiFi | {'links': [{'source': 'gateway_1', 'target': 'server_1', 'source_mininet': 'ap1', 'target_mininet': 'h1', 'created': True}]}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Engine marcada como construida | {'name': 'mininet_wifi_engine', 'engine_type': 'mininet_wifi', 'is_built': True, 'is_running': False, 'started_at': None, 'stopped_at': None, 'metadata': {'ip_base': '10.0.0.', 'ip_prefix': 24, 'ssid': 'pqc_iot_sim', 'mode': 'g', 'channel': '1', 'default_bw': 10, 'default_delay': '5ms', 'default_loss': 0, 'auto_set_positions': True, 'open_cli_on_start': False, 'link_mode': 'infrastructure', 'station_range': 200, 'ap_range': 200, 'association_wait_seconds': 1.0}}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Mininet WiFi build concluido | {'stations': 7, 'gateways': 1, 'servers': 1, 'links': 1, 'link_mode': 'infrastructure'}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Iniciando Mininet WiFi | {}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Engine marcada como iniciada | {'name': 'mininet_wifi_engine', 'engine_type': 'mininet_wifi', 'is_built': True, 'is_running': True, 'started_at': '2026/04/27 20:44:08', 'stopped_at': None, 'metadata': {'ip_base': '10.0.0.', 'ip_prefix': 24, 'ssid': 'pqc_iot_sim', 'mode': 'g', 'channel': '1', 'default_bw': 10, 'default_delay': '5ms', 'default_loss': 0, 'auto_set_positions': True, 'open_cli_on_start': False, 'link_mode': 'infrastructure', 'station_range': 200, 'ap_range': 200, 'association_wait_seconds': 1.0}}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Mininet WiFi iniciado | {'running': True, 'access_points': ['ap1']}
# [INFO] 2026/04/27 20:44:08 | mininet_wifi_engine | Interfaces WiFi das stations ativadas | {'interfaces': [{'node_id': 'iot_1', 'station': 'sta1', 'interface': 'sta1-wlan0', 'output': ''}, {'node_id': 'iot_2', 'station': 'sta2', 'interface': 'sta2-wlan0', 'output': ''}, {'node_id': 'iot_3', 'station': 'sta3', 'interface': 'sta3-wlan0', 'output': ''}, {'node_id': 'iot_6', 'station': 'sta6', 'interface': 'sta6-wlan0', 'output': ''}, {'node_id': 'iot_5', 'station': 'sta5', 'interface': 'sta5-wlan0', 'output': ''}, {'node_id': 'iot_4', 'station': 'sta4', 'interface': 'sta4-wlan0', 'output': ''}, {'node_id': 'iot_7', 'station': 'sta7', 'interface': 'sta7-wlan0', 'output': ''}]}
# sta2 is already connected!
# [INFO] 2026/04/27 20:44:09 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_1', 'station': 'sta1', 'ap': 'ap1', 'interface': 'sta1-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta1-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1717 bytes (30 packets)\r\n\tTX: 565 bytes (6 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 9.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta1-wlan0 proto kernel scope link src 10.0.0.1', 'addr_status': '420: sta1-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:00:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.1/24 brd 10.0.0.255 scope global sta1-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::1/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:0/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta1-wlan0 up': '', 'iw dev sta1-wlan0 disconnect': '', 'iw dev sta1-wlan0 connect pqc_iot_sim_ap1': ''}}
# sta3 is already connected!
# [INFO] 2026/04/27 20:44:10 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_2', 'station': 'sta2', 'ap': 'ap1', 'interface': 'sta2-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta2-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1941 bytes (32 packets)\r\n\tTX: 461 bytes (5 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 6.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta2-wlan0 proto kernel scope link src 10.0.0.2', 'addr_status': '421: sta2-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:01:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.2/24 brd 10.0.0.255 scope global sta2-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::2/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:100/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta2-wlan0 up': '', 'iw dev sta2-wlan0 disconnect': '', 'iw dev sta2-wlan0 connect pqc_iot_sim_ap1': ''}}
# sta6 is already connected!
# [INFO] 2026/04/27 20:44:11 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_3', 'station': 'sta3', 'ap': 'ap1', 'interface': 'sta3-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta3-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1829 bytes (31 packets)\r\n\tTX: 565 bytes (6 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 9.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta3-wlan0 proto kernel scope link src 10.0.0.3', 'addr_status': '422: sta3-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:02:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.3/24 brd 10.0.0.255 scope global sta3-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::3/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:200/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta3-wlan0 up': '', 'iw dev sta3-wlan0 disconnect': '', 'iw dev sta3-wlan0 connect pqc_iot_sim_ap1': ''}}
# sta5 is already connected!
# [INFO] 2026/04/27 20:44:12 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_6', 'station': 'sta6', 'ap': 'ap1', 'interface': 'sta6-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta6-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 3137 bytes (42 packets)\r\n\tTX: 565 bytes (6 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 1.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta6-wlan0 proto kernel scope link src 10.0.0.4', 'addr_status': '423: sta6-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:03:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.4/24 brd 10.0.0.255 scope global sta6-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::4/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:300/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta6-wlan0 up': '', 'iw dev sta6-wlan0 disconnect': '', 'iw dev sta6-wlan0 connect pqc_iot_sim_ap1': ''}}
# sta4 is already connected!
# [INFO] 2026/04/27 20:44:13 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_5', 'station': 'sta5', 'ap': 'ap1', 'interface': 'sta5-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta5-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 2521 bytes (37 packets)\r\n\tTX: 701 bytes (7 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 9.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta5-wlan0 proto kernel scope link src 10.0.0.5', 'addr_status': '424: sta5-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:04:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.5/24 brd 10.0.0.255 scope global sta5-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::5/64 scope global \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:400/64 scope link \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta5-wlan0 up': '', 'iw dev sta5-wlan0 disconnect': '', 'iw dev sta5-wlan0 connect pqc_iot_sim_ap1': ''}}
# sta7 is already connected!
# [INFO] 2026/04/27 20:44:14 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_4', 'station': 'sta4', 'ap': 'ap1', 'interface': 'sta4-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta4-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1857 bytes (31 packets)\r\n\tTX: 701 bytes (7 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 9.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta4-wlan0 proto kernel scope link src 10.0.0.6', 'addr_status': '425: sta4-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:05:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.6/24 brd 10.0.0.255 scope global sta4-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::6/64 scope global \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:500/64 scope link \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta4-wlan0 up': '', 'iw dev sta4-wlan0 disconnect': '', 'iw dev sta4-wlan0 connect pqc_iot_sim_ap1': ''}}
# [INFO] 2026/04/27 20:44:15 | mininet_wifi_engine | Tentativa de associacao wireless executada | {'node_id': 'iot_7', 'station': 'sta7', 'ap': 'ap1', 'interface': 'sta7-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta7-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1385 bytes (27 packets)\r\n\tTX: 357 bytes (4 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 1.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta7-wlan0 proto kernel scope link src 10.0.0.7', 'addr_status': '426: sta7-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:06:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.7/24 brd 10.0.0.255 scope global sta7-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::7/64 scope global \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:600/64 scope link \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta7-wlan0 up': '', 'iw dev sta7-wlan0 disconnect': '', 'iw dev sta7-wlan0 connect pqc_iot_sim_ap1': ''}}
# [INFO] 2026/04/27 20:44:15 | mininet_wifi_engine | Associacao wireless concluida | {'ap': 'ap1', 'ssid': 'pqc_iot_sim_ap1', 'associated': [{'node_id': 'iot_1', 'station': 'sta1', 'ap': 'ap1', 'interface': 'sta1-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta1-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1717 bytes (30 packets)\r\n\tTX: 565 bytes (6 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 9.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta1-wlan0 proto kernel scope link src 10.0.0.1', 'addr_status': '420: sta1-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:00:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.1/24 brd 10.0.0.255 scope global sta1-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::1/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:0/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta1-wlan0 up': '', 'iw dev sta1-wlan0 disconnect': '', 'iw dev sta1-wlan0 connect pqc_iot_sim_ap1': ''}}, {'node_id': 'iot_2', 'station': 'sta2', 'ap': 'ap1', 'interface': 'sta2-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta2-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1941 bytes (32 packets)\r\n\tTX: 461 bytes (5 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 6.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta2-wlan0 proto kernel scope link src 10.0.0.2', 'addr_status': '421: sta2-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:01:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.2/24 brd 10.0.0.255 scope global sta2-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::2/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:100/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta2-wlan0 up': '', 'iw dev sta2-wlan0 disconnect': '', 'iw dev sta2-wlan0 connect pqc_iot_sim_ap1': ''}}, {'node_id': 'iot_3', 'station': 'sta3', 'ap': 'ap1', 'interface': 'sta3-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta3-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 1829 bytes (31 packets)\r\n\tTX: 565 bytes (6 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 9.0 MBit/s\r\n\tbss flags: short-slot-time\r\n\tdtim period: 2\r\n\tbeacon int: 100', 'route_status': '10.0.0.0/24 dev sta3-wlan0 proto kernel scope link src 10.0.0.3', 'addr_status': '422: sta3-wlan0: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc netem state UP group default qlen 1000\r\n    link/ether 02:00:00:00:02:00 brd ff:ff:ff:ff:ff:ff\r\n    inet 10.0.0.3/24 brd 10.0.0.255 scope global sta3-wlan0\r\n       valid_lft forever preferred_lft forever\r\n    inet6 2001::3/64 scope global tentative \r\n       valid_lft forever preferred_lft forever\r\n    inet6 fe80::ff:fe00:200/64 scope link tentative \r\n       valid_lft forever preferred_lft forever', 'outputs': {'setAssociation': 'None', 'ip link set sta3-wlan0 up': '', 'iw dev sta3-wlan0 disconnect': '', 'iw dev sta3-wlan0 connect pqc_iot_sim_ap1': ''}}, {'node_id': 'iot_6', 'station': 'sta6', 'ap': 'ap1', 'interface': 'sta6-wlan0', 'ssid': 'pqc_iot_sim_ap1', 'connected': True, 'link_status': 'Connected to 02:00:00:00:07:00 (on sta6-wlan0)\r\n\tSSID: pqc_iot_sim_ap1\r\n\tfreq: 2412.0\r\n\tRX: 3137 bytes (42 packets)\r\n\tTX: 565 bytes (6 packets)\r\n\tsignal: -41 dBm\r\n\ttx bitrate: 1.0 MBit/s\r\n\tbss flags: short-slot-time\r ...
# [INFO] 2026/04/27 20:44:15 | mininet_wifi_engine | Comando OVS executado | {'ap': 'ap1', 'command': 'ovs-vsctl set-fail-mode ap1 standalone', 'returncode': 0, 'stdout': '', 'stderr': ''}
# [INFO] 2026/04/27 20:44:15 | mininet_wifi_engine | Comando OVS executado | {'ap': 'ap1', 'command': 'ovs-ofctl del-flows ap1', 'returncode': 0, 'stdout': '', 'stderr': ''}
# [INFO] 2026/04/27 20:44:15 | mininet_wifi_engine | Comando OVS executado | {'ap': 'ap1', 'command': 'ovs-ofctl add-flow ap1 priority=0,actions=NORMAL', 'returncode': 0, 'stdout': '', 'stderr': ''}
# [INFO] 2026/04/27 20:44:17 | mininet_wifi_engine | Cache ARP apagado nos nos da engine | {'iot_1': '', 'iot_2': '', 'iot_3': '', 'iot_6': '', 'iot_5': '', 'iot_4': '', 'iot_7': '', 'gateway_1': '', 'server_1': ''}
# [INFO] 2026/04/27 20:44:17 | mininet_wifi_engine | Configuracao pos inicio aplicada | {'link_mode': 'infrastructure', 'note': 'Stations associadas ao AP, interfaces WiFi ativadas e fluxo NORMAL aplicado.'}
# Engine iniciada

# %%
link_metrics = engine.collect_link_metrics(
    source=SOURCE,
    destination=DESTINATION
)

print(link_metrics)
# Out:
# [INFO] 2026/04/27 20:44:17 | mininet_wifi_engine | Executando comando em no da engine | {'node_id': 'iot_1', 'mininet_name': 'sta1', 'command': 'ping -c 3 10.0.0.200'}
# [INFO] 2026/04/27 20:44:19 | mininet_wifi_engine | Comando executado | {'node_id': 'iot_1', 'command': 'ping -c 3 10.0.0.200', 'output': 'PING 10.0.0.200 (10.0.0.200) 56(84) bytes of data.\r\n64 bytes from 10.0.0.200: icmp_seq=1 ttl=64 time=18.8 ms\r\n64 bytes from 10.0.0.200: icmp_seq=2 ttl=64 time=9.37 ms\r\n64 bytes from 10.0.0.200: icmp_seq=3 ttl=64 time=9.30 ms\r\n\r\n--- 10.0.0.200 ping statistics ---\r\n3 packets transmitted, 3 received, 0% packet loss, time 2003ms\r\nrtt min/avg/max/mdev = 9.298/12.486/18.791/4.457 ms'}
# [INFO] 2026/04/27 20:44:19 | mininet_wifi_engine | Metricas reais de link coletadas | {'source': 'iot_1', 'destination': 'server_1', 'latency_ms': 12.486, 'packet_loss_percent': 0.0, 'packets_transmitted': 3, 'packets_received': 3}
# {'source': 'iot_1', 'destination': 'server_1', 'destination_ip': '10.0.0.200', 'packet_loss_percent': 0.0, 'packets_transmitted': 3, 'packets_received': 3, 'rtt_min_ms': 9.298, 'rtt_avg_ms': 12.486, 'rtt_max_ms': 18.791, 'rtt_mdev_ms': 4.457, 'latency_ms': 12.486, 'raw_output': 'PING 10.0.0.200 (10.0.0.200) 56(84) bytes of data.\r\n64 bytes from 10.0.0.200: icmp_seq=1 ttl=64 time=18.8 ms\r\n64 bytes from 10.0.0.200: icmp_seq=2 ttl=64 time=9.37 ms\r\n64 bytes from 10.0.0.200: icmp_seq=3 ttl=64 time=9.30 ms\r\n\r\n--- 10.0.0.200 ping statistics ---\r\n3 packets transmitted, 3 received, 0% packet loss, time 2003ms\r\nrtt min/avg/max/mdev = 9.298/12.486/18.791/4.457 ms\r\n'}

# %%
send_result = rede.send(
    source=SOURCE,
    destination=DESTINATION,
    payload=PAYLOAD,
    link_metrics=link_metrics
)
# Out:
# [INFO] 2026/04/27 20:44:19 | Network | Iniciando criacao dos hosts | {'total_nodes': 9, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_1 | Host criado | {'host_id': 'iot_1', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_1 | No IoT inicializado | {'host_id': 'iot_1', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | iot_2 | Host criado | {'host_id': 'iot_2', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_2 | No IoT inicializado | {'host_id': 'iot_2', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | iot_3 | Host criado | {'host_id': 'iot_3', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_3 | No IoT inicializado | {'host_id': 'iot_3', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | iot_6 | Host criado | {'host_id': 'iot_6', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_6 | No IoT inicializado | {'host_id': 'iot_6', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | iot_5 | Host criado | {'host_id': 'iot_5', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_5 | No IoT inicializado | {'host_id': 'iot_5', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | iot_4 | Host criado | {'host_id': 'iot_4', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_4 | No IoT inicializado | {'host_id': 'iot_4', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | iot_7 | Host criado | {'host_id': 'iot_7', 'host_type': 'iot', 'energy': 100.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_7 | No IoT inicializado | {'host_id': 'iot_7', 'sensor_type': 'generic'}
# [INFO] 2026/04/27 20:44:19 | gateway_1 | Host criado | {'host_id': 'gateway_1', 'host_type': 'gateway', 'energy': 500.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | gateway_1 | Gateway inicializado | {'host_id': 'gateway_1'}
# [INFO] 2026/04/27 20:44:19 | server_1 | Host criado | {'host_id': 'server_1', 'host_type': 'server', 'energy': 1000.0, 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | server_1 | Servidor de aplicacao inicializado | {'host_id': 'server_1'}
# [INFO] 2026/04/27 20:44:19 | Network | Hosts criados com sucesso | {'hosts': ['iot_1', 'iot_2', 'iot_3', 'iot_6', 'iot_5', 'iot_4', 'iot_7', 'gateway_1', 'server_1'], 'total_hosts': 9}
# [INFO] 2026/04/27 20:44:19 | MetricsCollector | Snapshot de energia criado | {'hosts': ['iot_1', 'iot_2', 'iot_3', 'iot_6', 'iot_5', 'iot_4', 'iot_7', 'gateway_1', 'server_1']}
# [INFO] 2026/04/27 20:44:19 | CryptoManager | Payload protegido com criptografia hibrida real | {'algorithm': 'X25519 + Ed25519 + ML-KEM-512 + ML-DSA-44 + AES GCM', 'overhead_bytes': 5488, 'operation_time_seconds': 0.069748, 'energy_cost': 0.153258}
# [INFO] 2026/04/27 20:44:19 | iot_1 | Energia consumida | {'host_id': 'iot_1', 'amount': 0.153258, 'remaining_energy': 99.846742, 'reason': 'crypto_protect'}
# [INFO] 2026/04/27 20:44:19 | Network | Caminho calculado para envio | {'source': 'iot_1', 'destination': 'server_1', 'path': ['iot_1', 'iot_6', 'iot_7', 'gateway_1', 'server_1'], 'hops': 4}
# [INFO] 2026/04/27 20:44:19 | iot_1 | Energia consumida | {'host_id': 'iot_1', 'amount': 0.1, 'remaining_energy': 99.74674200000001, 'reason': 'send_data'}
# [INFO] 2026/04/27 20:44:19 | iot_1 | Pacote enviado | {'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}}}
# [INFO] 2026/04/27 20:44:19 | iot_6 | Energia consumida | {'host_id': 'iot_6', 'amount': 0.05, 'remaining_energy': 99.95, 'reason': 'receive_data'}
# [INFO] 2026/04/27 20:44:19 | iot_6 | Pacote recebido | {'receiver': 'iot_6', 'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}}}
# [INFO] 2026/04/27 20:44:19 | iot_6 | Energia consumida | {'host_id': 'iot_6', 'amount': 0.08, 'remaining_energy': 99.87, 'reason': 'forward_data'}
# [INFO] 2026/04/27 20:44:19 | iot_6 | Pacote encaminhado por no intermediario | {'host_id': 'iot_6', 'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | iot_7 | Energia consumida | {'host_id': 'iot_7', 'amount': 0.05, 'remaining_energy': 99.95, 'reason': 'receive_data'}
# [INFO] 2026/04/27 20:44:19 | iot_7 | Pacote recebido | {'receiver': 'iot_7', 'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}}}
# [INFO] 2026/04/27 20:44:19 | iot_7 | Energia consumida | {'host_id': 'iot_7', 'amount': 0.08, 'remaining_energy': 99.87, 'reason': 'forward_data'}
# [INFO] 2026/04/27 20:44:19 | iot_7 | Pacote encaminhado por no intermediario | {'host_id': 'iot_7', 'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | gateway_1 | Energia consumida | {'host_id': 'gateway_1', 'amount': 0.05, 'remaining_energy': 499.95, 'reason': 'receive_data'}
# [INFO] 2026/04/27 20:44:19 | gateway_1 | Pacote recebido | {'receiver': 'gateway_1', 'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}}}
# [INFO] 2026/04/27 20:44:19 | gateway_1 | Energia consumida | {'host_id': 'gateway_1', 'amount': 0.08, 'remaining_energy': 499.87, 'reason': 'forward_data'}
# [INFO] 2026/04/27 20:44:19 | gateway_1 | Pacote encaminhado pelo gateway | {'gateway': 'gateway_1', 'original_source': 'iot_1', 'new_destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid'}
# [INFO] 2026/04/27 20:44:19 | server_1 | Energia consumida | {'host_id': 'server_1', 'amount': 0.05, 'remaining_energy': 999.95, 'reason': 'receive_data'}
# [INFO] 2026/04/27 20:44:19 | server_1 | Pacote recebido | {'receiver': 'server_1', 'source': 'iot_1', 'destination': 'server_1', 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}}}
# [INFO] 2026/04/27 20:44:19 | server_1 | Dado processado pelo servidor | {'server_id': 'server_1', 'source': 'iot_1', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}}, 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'received_at': '2026/04/27 20:44:19'}
# [INFO] 2026/04/27 20:44:19 | MetricsCollector | Metrica de transmissao registrada | {'transmission_id': 1, 'source': 'iot_1', 'destination': 'server_1', 'status': 'delivered', 'hops': 4, 'total_energy_consumed': 0.693258, 'payload_size_bytes': 5607, 'crypto_overhead_bytes': 5488, 'crypto_time_seconds': 0.069748, 'crypto_energy_cost': 0.153258, 'link_latency_ms': 12.486, 'link_packet_loss_percent': 0.0, 'duration_seconds': 0.070462}
# [INFO] 2026/04/27 20:44:19 | Network | Envio concluido | {'source': 'iot_1', 'destination': 'server_1', 'path': ['iot_1', 'iot_6', 'iot_7', 'gateway_1', 'server_1'], 'hops': 4, 'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'crypto_overhead_bytes': 5488, 'crypto_time_seconds': 0.069748, 'crypto_energy_cost': 0.153258, 'link_metrics': {'source': 'iot_1', 'destination': 'server_1', 'destination_ip': '10.0.0.200', 'packet_loss_percent': 0.0, 'packets_transmitted': 3, 'packets_received': 3, 'rtt_min_ms': 9.298, 'rtt_avg_ms': 12.486, 'rtt_max_ms': 18.791, 'rtt_mdev_ms': 4.457, 'latency_ms': 12.486, 'raw_output': 'PING 10.0.0.200 (10.0.0.200) 56(84) bytes of data.\r\n64 bytes from 10.0.0.200: icmp_seq=1 ttl=64 time=18.8 ms\r\n64 bytes from 10.0.0.200: icmp_seq=2 ttl=64 time=9.37 ms\r\n64 bytes from 10.0.0.200: icmp_seq=3 ttl=64 time=9.30 ms\r\n\r\n--- 10.0.0.200 ping statistics ---\r\n3 packets transmitted, 3 received, 0% packet loss, time 2003ms\r\nrtt min/avg/max/mdev = 9.298/12.486/18.791/4.457 ms\r\n'}}

# %%
summary = rede.metrics()

print(summary)
# Out:
# [INFO] 2026/04/27 20:44:19 | MetricsCollector | Resumo de metricas solicitado | {'total_transmissions': 1, 'delivered': 1, 'failed': 0, 'delivery_rate': 1.0, 'total_energy_consumed': 0.693258, 'average_energy_consumed': 0.693258, 'average_hops': 4.0, 'average_duration_seconds': 0.070462, 'total_payload_bytes': 5607, 'total_original_payload_bytes': 103, 'total_protected_payload_bytes': 5607, 'total_crypto_overhead_bytes': 5488, 'average_crypto_overhead_bytes': 5488.0, 'total_crypto_time_seconds': 0.069748, 'average_crypto_time_seconds': 0.069748, 'total_crypto_energy_cost': 0.153258, 'average_crypto_energy_cost': 0.153258, 'average_link_latency_ms': 12.486, 'average_link_packet_loss_percent': 0.0, 'total_link_packets_transmitted': 3, 'total_link_packets_received': 3, 'link_delivery_rate': 1.0}
# {'total_transmissions': 1, 'delivered': 1, 'failed': 0, 'delivery_rate': 1.0, 'total_energy_consumed': 0.693258, 'average_energy_consumed': 0.693258, 'average_hops': 4.0, 'average_duration_seconds': 0.070462, 'total_payload_bytes': 5607, 'total_original_payload_bytes': 103, 'total_protected_payload_bytes': 5607, 'total_crypto_overhead_bytes': 5488, 'average_crypto_overhead_bytes': 5488.0, 'total_crypto_time_seconds': 0.069748, 'average_crypto_time_seconds': 0.069748, 'total_crypto_energy_cost': 0.153258, 'average_crypto_energy_cost': 0.153258, 'average_link_latency_ms': 12.486, 'average_link_packet_loss_percent': 0.0, 'total_link_packets_transmitted': 3, 'total_link_packets_received': 3, 'link_delivery_rate': 1.0}

# %%
transmissions = rede.transmissions()

if transmissions:
    print(transmissions[0])
else:
    print("Nenhuma transmissão registrada")
# Out:
# {'transmission_id': 1, 'source': 'iot_1', 'destination': 'server_1', 'status': 'delivered', 'delivered': True, 'path': ['iot_1', 'iot_6', 'iot_7', 'gateway_1', 'server_1'], 'hops': 4, 'protocol': 'mqtt', 'crypto_mode': 'hybrid', 'payload_size_bytes': 5607, 'original_payload_size_bytes': 103, 'protected_payload_size_bytes': 5607, 'crypto_backend': 'cryptography + liboqs', 'crypto_algorithm': 'X25519 + Ed25519 + ML-KEM-512 + ML-DSA-44 + AES GCM', 'crypto_original_size_bytes': 103, 'crypto_protected_size_bytes': 5607, 'crypto_overhead_bytes': 5488, 'crypto_time_seconds': 0.069748, 'crypto_energy_cost': 0.153258, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption': {'algorithm': 'AES GCM', 'nonce_size': 12, 'ciphertext_size': 119, 'tag_size': 16, 'ciphertext_sha256': '0d1a58a67f214b299381cfb2ab8ab639b26d75ea46376199b986b5cc9b0527f6', 'nonce_sha256': '9a508614bec9ed23c8fcb3e23e2de56e8fb4e7df0cb47bb2823b3cff3fc708e5'}}, 'link_latency_ms': 12.486, 'link_packet_loss_percent': 0.0, 'link_packets_transmitted': 3, 'link_packets_received': 3, 'link_rtt_min_ms': 9.298, 'link_rtt_avg_ms': 12.486, 'link_rtt_max_ms': 18.791, 'link_rtt_mdev_ms': 4.457, 'link_metrics': {'source': 'iot_1', 'destination': 'server_1', 'destination_ip': '10.0.0.200', 'packet_loss_percent': 0.0, 'packets_transmitted': 3, 'packets_received': 3, 'rtt_min_ms': 9.298, 'rtt_avg_ms': 12.486, 'rtt_max_ms': 18.791, 'rtt_mdev_ms': 4.457, 'latency_ms': 12.486, 'raw_output': 'PING 10.0.0.200 (10.0.0.200) 56(84) bytes of data.\r\n64 bytes from 10.0.0.200: icmp_seq=1 ttl=64 time=18.8 ms\r\n64 bytes from 10.0.0.200: icmp_seq=2 ttl=64 time=9.37 ms\r\n64 bytes from 10.0.0.200: icmp_seq=3 ttl=64 time=9.30 ms\r\n\r\n--- 10.0.0.200 ping statistics ---\r\n3 packets transmitted, 3 received, 0% packet loss, time 2003ms\r\nrtt min/avg/max/mdev = 9.298/12.486/18.791/4.457 ms\r\n'}, 'started_at': '2026/04/27 20:44:19', 'finished_at': '2026/04/27 20:44:19', 'duration_seconds': 0.070462, 'energy_consumed_by_host': {'iot_1': 0.253258, 'iot_2': 0.0, 'iot_3': 0.0, 'iot_6': 0.13, 'iot_5': 0.0, 'iot_4': 0.0, 'iot_7': 0.13, 'gateway_1': 0.13, 'server_1': 0.05}, 'total_energy_consumed': 0.693258, 'result': {'status': 'delivered', 'path': ['iot_1', 'iot_6', 'iot_7', 'gateway_1', 'server_1'], 'crypto': {'mode': 'hybrid', 'backend': 'cryptography + liboqs', 'algorithm': 'X25519 + Ed25519 + ML-KEM-512 + ML-DSA-44 + AES GCM', 'payload': {'crypto_mode': 'hybrid', 'crypto_backend': 'cryptography + liboqs', 'encrypted': True, 'payload_original_sha256': '62696861e1f1c3833fcc1f065204f15ee5c8515aba08c36be51952fbde86e0c5', 'original_size_bytes': 103, 'protected_size_bytes': 5607, 'overhead_bytes': 5488, 'crypto_metadata': {'classical_kex': {'algorithm': 'X25519', 'sender_public_key_size': 32, 'receiver_public_key_size': 32, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'pqc_kem': {'algorithm': 'ML-KEM-512', 'public_key_size': 800, 'ciphertext_size': 768, 'shared_secret_size': 32, 'shared_secret_valid': True}, 'classical_signature': {'algorithm': 'Ed25519', 'public_key_size': 32, 'signature_size': 64, 'signature_valid': True}, 'pqc_signature': {'algorithm': 'ML-DSA-44', 'public_key_size': 1312, 'signature_size': 2420, 'signature_valid': True}, 'hybrid_secret': {'combination': 'SHA256 de segredo classico concatenado com segredo PQC', 'combined_secret_size': 32}, 'encryption' ...

# %%
engine.stop()

print("Engine parada")
# Out:
# [INFO] 2026/04/27 20:44:19 | mininet_wifi_engine | Parando Mininet WiFi | {}
# *** Stopping 1 controllers
# c0
# *** Stopping 9 links
# .........
# *** Stopping switches/access points
# ap1
# *** Stopping nodes
# h1 sta1 sta2 sta3 sta6 sta5 sta4 sta7
#
# *** Removing WiFi module and Configurations
# *** Killing mac80211_hwsim
#
# *** Done
# [INFO] 2026/04/27 20:44:21 | mininet_wifi_engine | Engine marcada como parada | {'name': 'mininet_wifi_engine', 'engine_type': 'mininet_wifi', 'is_built': True, 'is_running': False, 'started_at': '2026/04/27 20:44:08', 'stopped_at': '2026/04/27 20:44:21', 'metadata': {'ip_base': '10.0.0.', 'ip_prefix': 24, 'ssid': 'pqc_iot_sim', 'mode': 'g', 'channel': '1', 'default_bw': 10, 'default_delay': '5ms', 'default_loss': 0, 'auto_set_positions': True, 'open_cli_on_start': False, 'link_mode': 'infrastructure', 'station_range': 200, 'ap_range': 200, 'association_wait_seconds': 1.0}}
# [INFO] 2026/04/27 20:44:21 | mininet_wifi_engine | Mininet WiFi parado | {}
# Engine parada
